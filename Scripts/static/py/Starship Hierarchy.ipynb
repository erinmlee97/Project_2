# %%
import pandas as pd

# %%
df = pd.read_csv("../data/starships.csv")

# %%
starships_df = pd.DataFrame(df)
starships_df.head()
# Out:
#                            name                            model  \
# 0                 CR90 corvette                    CR90 corvette
# 1                Star Destroyer  Imperial I-class Star Destroyer
# 2  Sentinel-class landing craft     Sentinel-class landing craft
# 3                    Death Star      DS-1 Orbital Battle Station
# 4             Millennium Falcon          YT-1300 light freighter
#
#                                         manufacturer cost_in_credits  length  \
# 0                  Corellian Engineering Corporation         3500000     150
# 1                                   Kuat Drive Yards       150000000   1,600
# 2            Sienar Fleet Systems, Cyngus Spaceworks          240000      38
# 3  Imperial Department of Military Research, Sien...   1000000000000  120000
# 4                  Corellian Engineering Corporation          100000   34.37
#
#   max_atmosphering_speed     crew passengers cargo_capacity consumables  \
# 0                    950   30-165        600        3000000      1 year
# 1                    975   47,060        NaN       36000000     2 years
# 2                   1000        5         75         180000     1 month
# 3                    NaN  342,953    843,342  1000000000000     3 years
# 4                   1050        4          6         100000    2 months
#
#   hyperdrive_rating MGLT                   starship_class
# 0               2.0   60                         corvette
# 1               2.0   60                   Star Destroyer
# 2               1.0   70                    landing craft
# 3               4.0   10  Deep Space Mobile Battlestation
# 4               0.5   75                  Light freighter

# %%
starships_df =starships_df.drop(columns=["model", "manufacturer", "length", "max_atmosphering_speed", "crew", "cargo_capacity", "consumables", "MGLT"])
starships_df.head()
# Out:
#                            name cost_in_credits passengers hyperdrive_rating  \
# 0                 CR90 corvette         3500000        600               2.0
# 1                Star Destroyer       150000000        NaN               2.0
# 2  Sentinel-class landing craft          240000         75               1.0
# 3                    Death Star   1000000000000    843,342               4.0
# 4             Millennium Falcon          100000          6               0.5
#
#                     starship_class
# 0                         corvette
# 1                   Star Destroyer
# 2                    landing craft
# 3  Deep Space Mobile Battlestation
# 4                  Light freighter

# %%
starships_df = starships_df[['hyperdrive_rating', 'starship_class', 'name', 'cost_in_credits', 'passengers']]
starships_df
# Out:
#    hyperdrive_rating                   starship_class  \
# 0                2.0                         corvette
# 1                2.0                   Star Destroyer
# 2                1.0                    landing craft
# 3                4.0  Deep Space Mobile Battlestation
# 4                0.5                  Light freighter
# 5                1.0              assault starfighter
# 6                1.0                      Starfighter
# 7                1.0                      Starfighter
# 8                2.0                 Star dreadnought
# 9                4.0                 Medium transport
# 10               3.0                     Patrol craft
# 11               1.0       Armed government transport
# 12               2.0                      Escort ship
# 13               1.0                     Star Cruiser
# 14               1.0                      Starfighter
# 15               2.0              Assault Starfighter
# 16               2.0                    Space cruiser
# 17               2.0               Droid control ship
# 18               1.0                      Starfighter
# 19               1.8                            yacht
# 20               1.5                  Space Transport
# 21               0.7                 Diplomatic barge
# 22           unknown                        freighter
# 23               1.0                      Starfighter
# 24               0.9                            yacht
# 25               0.6                     assault ship
# 26               1.5                            yacht
# 27               1.5                     capital ship
# 28               1.0                        transport
# 29               1.0                   star destroyer
# 30               0.5                            yacht
# 31               1.0                      starfighter
# 32               1.0                      starfighter
# 33               1.0                          cruiser
# 34                 6                      starfighter
# 35               1.0                      starfighter
#
#                              name cost_in_credits passengers
# 0                   CR90 corvette         3500000        600
# 1                  Star Destroyer       150000000        NaN
# 2    Sentinel-class landing craft          240000         75
# 3                      Death Star   1000000000000    843,342
# 4               Millennium Falcon          100000          6
# 5                          Y-wing          134999          0
# 6                          X-wing          149999          0
# 7                 TIE Advanced x1         unknown          0
# 8                        Executor      1143350000      38000
# 9                 Rebel transport         unknown         90
# 10                        Slave 1         unknown          6
# 11               Imperial shuttle          240000         20
# 12  EF76 Nebulon-B escort frigate         8500000         75
# 13               Calamari Cruiser       104000000       1200
# 14                         A-wing          175000          0
# 15                         B-wing          220000          0
# 16               Republic Cruiser         unknown         16
# 17             Droid control ship         unknown     139000
# 18                  Naboo fighter          200000          0
# 19           Naboo Royal Starship         unknown    unknown
# 20                       Scimitar        55000000          6
# 21        J-type diplomatic barge         2000000         10
# 22       AA-9 Coruscant freighter         unknown      30000
# 23               Jedi starfighter          180000          0
# 24            H-type Nubian yacht         unknown    unknown
# 25          Republic Assault ship         unknown      16000
# 26                   Solar Sailer           35700         11
# 27       Trade Federation cruiser       125000000      48247
# 28       Theta-class T-2c shuttle         1000000         16
# 29        Republic attack cruiser        59000000       2000
# 30               Naboo star skiff         unknown          3
# 31               Jedi Interceptor          320000          0
# 32                        arc-170          155000          0
# 33            Banking clan frigte        57000000    unknown
# 34       Belbullab-22 starfighter          168000          0
# 35                         V-wing          102500          0

# %%
starships_df.sort_values(by=['hyperdrive_rating', 'starship_class'])
# Out:
#    hyperdrive_rating                   starship_class  \
# 4                0.5                  Light freighter
# 30               0.5                            yacht
# 25               0.6                     assault ship
# 21               0.7                 Diplomatic barge
# 24               0.9                            yacht
# 11               1.0       Armed government transport
# 13               1.0                     Star Cruiser
# 6                1.0                      Starfighter
# 7                1.0                      Starfighter
# 14               1.0                      Starfighter
# 18               1.0                      Starfighter
# 23               1.0                      Starfighter
# 5                1.0              assault starfighter
# 33               1.0                          cruiser
# 2                1.0                    landing craft
# 29               1.0                   star destroyer
# 31               1.0                      starfighter
# 32               1.0                      starfighter
# 35               1.0                      starfighter
# 28               1.0                        transport
# 20               1.5                  Space Transport
# 27               1.5                     capital ship
# 26               1.5                            yacht
# 19               1.8                            yacht
# 15               2.0              Assault Starfighter
# 17               2.0               Droid control ship
# 12               2.0                      Escort ship
# 16               2.0                    Space cruiser
# 1                2.0                   Star Destroyer
# 8                2.0                 Star dreadnought
# 0                2.0                         corvette
# 10               3.0                     Patrol craft
# 3                4.0  Deep Space Mobile Battlestation
# 9                4.0                 Medium transport
# 34                 6                      starfighter
# 22           unknown                        freighter
#
#                              name cost_in_credits passengers
# 4               Millennium Falcon          100000          6
# 30               Naboo star skiff         unknown          3
# 25          Republic Assault ship         unknown      16000
# 21        J-type diplomatic barge         2000000         10
# 24            H-type Nubian yacht         unknown    unknown
# 11               Imperial shuttle          240000         20
# 13               Calamari Cruiser       104000000       1200
# 6                          X-wing          149999          0
# 7                 TIE Advanced x1         unknown          0
# 14                         A-wing          175000          0
# 18                  Naboo fighter          200000          0
# 23               Jedi starfighter          180000          0
# 5                          Y-wing          134999          0
# 33            Banking clan frigte        57000000    unknown
# 2    Sentinel-class landing craft          240000         75
# 29        Republic attack cruiser        59000000       2000
# 31               Jedi Interceptor          320000          0
# 32                        arc-170          155000          0
# 35                         V-wing          102500          0
# 28       Theta-class T-2c shuttle         1000000         16
# 20                       Scimitar        55000000          6
# 27       Trade Federation cruiser       125000000      48247
# 26                   Solar Sailer           35700         11
# 19           Naboo Royal Starship         unknown    unknown
# 15                         B-wing          220000          0
# 17             Droid control ship         unknown     139000
# 12  EF76 Nebulon-B escort frigate         8500000         75
# 16               Republic Cruiser         unknown         16
# 1                  Star Destroyer       150000000        NaN
# 8                        Executor      1143350000      38000
# 0                   CR90 corvette         3500000        600
# 10                        Slave 1         unknown          6
# 3                      Death Star   1000000000000    843,342
# 9                 Rebel transport         unknown         90
# 34       Belbullab-22 starfighter          168000          0
# 22       AA-9 Coruscant freighter         unknown      30000

# %%
starships_df = df.iloc[df.starship_class.str.lower()]

# %%
starships_df.to_json("../js/starship_hierarchy.json")
