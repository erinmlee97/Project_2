# %%
import pandas as pd

# %%
import requests
response = requests.get("https://swapi.dev/api/planets")
data = response.json()
data
# Out:
# {'count': 60,
#  'next': 'http://swapi.dev/api/planets/?page=2',
#  'previous': None,
#  'results': [{'name': 'Tatooine',
#    'rotation_period': '23',
#    'orbital_period': '304',
#    'diameter': '10465',
#    'climate': 'arid',
#    'gravity': '1 standard',
#    'terrain': 'desert',
#    'surface_water': '1',
#    'population': '200000',
#    'residents': ['http://swapi.dev/api/people/1/',
#     'http://swapi.dev/api/people/2/',
#     'http://swapi.dev/api/people/4/',
#     'http://swapi.dev/api/people/6/',
#     'http://swapi.dev/api/people/7/',
#     'http://swapi.dev/api/people/8/',
#     'http://swapi.dev/api/people/9/',
#     'http://swapi.dev/api/people/11/',
#     'http://swapi.dev/api/people/43/',
#     'http://swapi.dev/api/people/62/'],
#    'films': ['http://swapi.dev/api/films/1/',
#     'http://swapi.dev/api/films/3/',
#     'http://swapi.dev/api/films/4/',
#     'http://swapi.dev/api/films/5/',
#     'http://swapi.dev/api/films/6/'],
# ...

# %%
# Start with an empty list
planets = []

# Grab the search results
print("Downloading the original search results")
response = requests.get("https://swapi.dev/api/planets/")
data = response.json()

# Store the first page of results
planets = planets + data['results']

# While data['next'] isn't empty, let's download the next page, too
while data['next'] is not None:
    print("Next page found, downloading", data['next'])
    response = requests.get(data['next'])
    data = response.json()
    # Store the current page of results
    planets = planets + data['results']

print("We have", len(planets), "total results")
# Out:
# ...
# Next page found, downloading http://swapi.dev/api/planets/?page=2
# Next page found, downloading http://swapi.dev/api/planets/?page=3
# Next page found, downloading http://swapi.dev/api/planets/?page=4
# Next page found, downloading http://swapi.dev/api/planets/?page=5
# Next page found, downloading http://swapi.dev/api/planets/?page=6
# We have 60 total results

# %%
planets
# Out:
# [{'name': 'Tatooine',
#   'rotation_period': '23',
#   'orbital_period': '304',
#   'diameter': '10465',
#   'climate': 'arid',
#   'gravity': '1 standard',
#   'terrain': 'desert',
#   'surface_water': '1',
#   'population': '200000',
#   'residents': ['http://swapi.dev/api/people/1/',
#    'http://swapi.dev/api/people/2/',
#    'http://swapi.dev/api/people/4/',
#    'http://swapi.dev/api/people/6/',
#    'http://swapi.dev/api/people/7/',
#    'http://swapi.dev/api/people/8/',
#    'http://swapi.dev/api/people/9/',
#    'http://swapi.dev/api/people/11/',
#    'http://swapi.dev/api/people/43/',
#    'http://swapi.dev/api/people/62/'],
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/3/',
#    'http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'created': '2014-12-09T13:50:49.641000Z',
#   'edited': '2014-12-20T20:58:18.411000Z',
#   'url': 'http://swapi.dev/api/planets/1/'},
# ...

# %%
# Start with an empty list
starships = []

# Grab the search results
print("Downloading the original search results")
response = requests.get("https://swapi.dev/api/starships/")
data = response.json()

# Store the first page of results
starships = starships + data['results']

# While data['next'] isn't empty, let's download the next page, too
while data['next'] is not None:
    print("Next page found, downloading", data['next'])
    response = requests.get(data['next'])
    data = response.json()
    # Store the current page of results
    starships = starships + data['results']

print("We have", len(starships), "total results")
# Out:
# ...
# Next page found, downloading http://swapi.dev/api/starships/?page=2
# Next page found, downloading http://swapi.dev/api/starships/?page=3
# Next page found, downloading http://swapi.dev/api/starships/?page=4
# We have 36 total results

# %%
starships
# Out:
# [{'name': 'CR90 corvette',
#   'model': 'CR90 corvette',
#   'manufacturer': 'Corellian Engineering Corporation',
#   'cost_in_credits': '3500000',
#   'length': '150',
#   'max_atmosphering_speed': '950',
#   'crew': '30-165',
#   'passengers': '600',
#   'cargo_capacity': '3000000',
#   'consumables': '1 year',
#   'hyperdrive_rating': '2.0',
#   'MGLT': '60',
#   'starship_class': 'corvette',
#   'pilots': [],
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/3/',
#    'http://swapi.dev/api/films/6/'],
#   'created': '2014-12-10T14:20:33.369000Z',
#   'edited': '2014-12-20T21:23:49.867000Z',
#   'url': 'http://swapi.dev/api/starships/2/'},
#  {'name': 'Star Destroyer',
#   'model': 'Imperial I-class Star Destroyer',
#   'manufacturer': 'Kuat Drive Yards',
#   'cost_in_credits': '150000000',
#   'length': '1,600',
#   'max_atmosphering_speed': '975',
#   'crew': '47,060',
#   'passengers': 'n/a',
#   'cargo_capacity': '36000000',
# ...

# %%
# Start with an empty list
species = []

# Grab the search results
print("Downloading the original search results")
response = requests.get("https://swapi.dev/api/species/")
data = response.json()

# Store the first page of results
species = species + data['results']

# While data['next'] isn't empty, let's download the next page, too
while data['next'] is not None:
    print("Next page found, downloading", data['next'])
    response = requests.get(data['next'])
    data = response.json()
    # Store the current page of results
    species = species + data['results']

print("We have", len(species), "total results")
# Out:
# ...
# Next page found, downloading http://swapi.dev/api/species/?page=2
# Next page found, downloading http://swapi.dev/api/species/?page=3
# Next page found, downloading http://swapi.dev/api/species/?page=4
# We have 37 total results

# %%
species
# Out:
# [{'name': 'Human',
#   'classification': 'mammal',
#   'designation': 'sentient',
#   'average_height': '180',
#   'skin_colors': 'caucasian, black, asian, hispanic',
#   'hair_colors': 'blonde, brown, black, red',
#   'eye_colors': 'brown, blue, green, hazel, grey, amber',
#   'average_lifespan': '120',
#   'homeworld': 'http://swapi.dev/api/planets/9/',
#   'language': 'Galactic Basic',
#   'people': ['http://swapi.dev/api/people/66/',
#    'http://swapi.dev/api/people/67/',
#    'http://swapi.dev/api/people/68/',
#    'http://swapi.dev/api/people/74/'],
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/2/',
#    'http://swapi.dev/api/films/3/',
#    'http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'created': '2014-12-10T13:52:11.567000Z',
#   'edited': '2014-12-20T21:36:42.136000Z',
#   'url': 'http://swapi.dev/api/species/1/'},
#  {'name': 'Droid',
#   'classification': 'artificial',
# ...

# %%
# Start with an empty list
vehicles = []

# Grab the search results
print("Downloading the original search results")
response = requests.get("https://swapi.dev/api/vehicles/")
data = response.json()

# Store the first page of results
vehicles = vehicles + data['results']

# While data['next'] isn't empty, let's download the next page, too
while data['next'] is not None:
    print("Next page found, downloading", data['next'])
    response = requests.get(data['next'])
    data = response.json()
    # Store the current page of results
    vehicles = vehicles + data['results']

print("We have", len(vehicles), "total results")
# Out:
# ...
# Next page found, downloading http://swapi.dev/api/vehicles/?page=2
# Next page found, downloading http://swapi.dev/api/vehicles/?page=3
# Next page found, downloading http://swapi.dev/api/vehicles/?page=4
# We have 39 total results

# %%
vehicles
# Out:
# [{'name': 'Sand Crawler',
#   'model': 'Digger Crawler',
#   'manufacturer': 'Corellia Mining Corporation',
#   'cost_in_credits': '150000',
#   'length': '36.8 ',
#   'max_atmosphering_speed': '30',
#   'crew': '46',
#   'passengers': '30',
#   'cargo_capacity': '50000',
#   'consumables': '2 months',
#   'vehicle_class': 'wheeled',
#   'pilots': [],
#   'films': ['http://swapi.dev/api/films/1/', 'http://swapi.dev/api/films/5/'],
#   'created': '2014-12-10T15:36:25.724000Z',
#   'edited': '2014-12-20T21:30:21.661000Z',
#   'url': 'http://swapi.dev/api/vehicles/4/'},
#  {'name': 'T-16 skyhopper',
#   'model': 'T-16 skyhopper',
#   'manufacturer': 'Incom Corporation',
#   'cost_in_credits': '14500',
#   'length': '10.4 ',
#   'max_atmosphering_speed': '1200',
#   'crew': '1',
#   'passengers': '1',
#   'cargo_capacity': '50',
#   'consumables': '0',
#   'vehicle_class': 'repulsorcraft',
#   'pilots': [],
#   'films': ['http://swapi.dev/api/films/1/'],
# ...

# %%
planets_df= pd.DataFrame(planets)
planets_df.head()
# Out:
#        name rotation_period orbital_period diameter              climate  \
# 0  Tatooine              23            304    10465                 arid
# 1  Alderaan              24            364    12500            temperate
# 2  Yavin IV              24           4818    10200  temperate, tropical
# 3      Hoth              23            549     7200               frozen
# 4   Dagobah              23            341     8900                murky
#
#         gravity                             terrain surface_water  population  \
# 0    1 standard                              desert             1      200000
# 1    1 standard               grasslands, mountains            40  2000000000
# 2    1 standard                 jungle, rainforests             8        1000
# 3  1.1 standard  tundra, ice caves, mountain ranges           100     unknown
# 4           N/A                      swamp, jungles             8     unknown
#
#                                            residents  \
# ...

# %%
planets_df = planets_df.drop(columns=["residents", "films", "created", "edited", "url"])
planets_df.head()
# Out:
#        name rotation_period orbital_period diameter              climate  \
# 0  Tatooine              23            304    10465                 arid
# 1  Alderaan              24            364    12500            temperate
# 2  Yavin IV              24           4818    10200  temperate, tropical
# 3      Hoth              23            549     7200               frozen
# 4   Dagobah              23            341     8900                murky
#
#         gravity                             terrain surface_water  population
# 0    1 standard                              desert             1      200000
# 1    1 standard               grasslands, mountains            40  2000000000
# 2    1 standard                 jungle, rainforests             8        1000
# 3  1.1 standard  tundra, ice caves, mountain ranges           100     unknown
# 4           N/A                      swamp, jungles             8     unknown

# %%
starships_df = pd.DataFrame(starships)
starships_df.head()
# Out:
#                            name                            model  \
# 0                 CR90 corvette                    CR90 corvette
# 1                Star Destroyer  Imperial I-class Star Destroyer
# 2  Sentinel-class landing craft     Sentinel-class landing craft
# 3                    Death Star      DS-1 Orbital Battle Station
# 4             Millennium Falcon          YT-1300 light freighter
#
#                                         manufacturer cost_in_credits  length  \
# 0                  Corellian Engineering Corporation         3500000     150
# 1                                   Kuat Drive Yards       150000000   1,600
# 2            Sienar Fleet Systems, Cyngus Spaceworks          240000      38
# 3  Imperial Department of Military Research, Sien...   1000000000000  120000
# 4                  Corellian Engineering Corporation          100000   34.37
#
#   max_atmosphering_speed     crew passengers cargo_capacity consumables  \
# ...

# %%
starships_df =starships_df.drop(columns=["pilots", "films", "created", "edited", "url"])
starships_df.head()
# Out:
#                            name                            model  \
# 0                 CR90 corvette                    CR90 corvette
# 1                Star Destroyer  Imperial I-class Star Destroyer
# 2  Sentinel-class landing craft     Sentinel-class landing craft
# 3                    Death Star      DS-1 Orbital Battle Station
# 4             Millennium Falcon          YT-1300 light freighter
#
#                                         manufacturer cost_in_credits  length  \
# 0                  Corellian Engineering Corporation         3500000     150
# 1                                   Kuat Drive Yards       150000000   1,600
# 2            Sienar Fleet Systems, Cyngus Spaceworks          240000      38
# 3  Imperial Department of Military Research, Sien...   1000000000000  120000
# 4                  Corellian Engineering Corporation          100000   34.37
#
#   max_atmosphering_speed     crew passengers cargo_capacity consumables  \
# ...

# %%
species_df = pd.DataFrame(species)
species_df.head()
# Out:
#      name classification designation average_height  \
# 0   Human         mammal    sentient            180
# 1   Droid     artificial    sentient            n/a
# 2  Wookie         mammal    sentient            210
# 3  Rodian       sentient   reptilian            170
# 4    Hutt      gastropod    sentient            300
#
#                          skin_colors                hair_colors  \
# 0  caucasian, black, asian, hispanic  blonde, brown, black, red
# 1                                n/a                        n/a
# 2                               gray               black, brown
# 3                        green, blue                        n/a
# 4                  green, brown, tan                        n/a
#
#                                 eye_colors average_lifespan  \
# 0   brown, blue, green, hazel, grey, amber              120
# 1                                      n/a       indefinite
# 2  blue, green, yellow, brown, golden, red              400
# ...

# %%
species_df = species_df.drop(columns=["people", "films", "created", "edited", "url", "homeworld"])
species_df.head()
# Out:
#      name classification designation average_height  \
# 0   Human         mammal    sentient            180
# 1   Droid     artificial    sentient            n/a
# 2  Wookie         mammal    sentient            210
# 3  Rodian       sentient   reptilian            170
# 4    Hutt      gastropod    sentient            300
#
#                          skin_colors                hair_colors  \
# 0  caucasian, black, asian, hispanic  blonde, brown, black, red
# 1                                n/a                        n/a
# 2                               gray               black, brown
# 3                        green, blue                        n/a
# 4                  green, brown, tan                        n/a
#
#                                 eye_colors average_lifespan        language
# 0   brown, blue, green, hazel, grey, amber              120  Galactic Basic
# 1                                      n/a       indefinite             n/a
# ...

# %%
vehicles_df = pd.DataFrame(vehicles)
vehicles_df.head()
# Out:
#                  name                           model  \
# 0        Sand Crawler                  Digger Crawler
# 1      T-16 skyhopper                  T-16 skyhopper
# 2    X-34 landspeeder                X-34 landspeeder
# 3  TIE/LN starfighter  Twin Ion Engine/Ln Starfighter
# 4         Snowspeeder                 t-47 airspeeder
#
#                   manufacturer cost_in_credits length max_atmosphering_speed  \
# 0  Corellia Mining Corporation          150000  36.8                      30
# 1            Incom Corporation           14500  10.4                    1200
# 2         SoroSuub Corporation           10550   3.4                     250
# 3         Sienar Fleet Systems         unknown    6.4                   1200
# 4            Incom corporation         unknown    4.5                    650
#
#   crew passengers cargo_capacity consumables  vehicle_class  \
# 0   46         30          50000    2 months        wheeled
# ...

# %%
vehicles_df = vehicles_df.drop(columns=["pilots", "films", "created", "edited", "url"])
vehicles_df.head()
# Out:
#                  name                           model  \
# 0        Sand Crawler                  Digger Crawler
# 1      T-16 skyhopper                  T-16 skyhopper
# 2    X-34 landspeeder                X-34 landspeeder
# 3  TIE/LN starfighter  Twin Ion Engine/Ln Starfighter
# 4         Snowspeeder                 t-47 airspeeder
#
#                   manufacturer cost_in_credits length max_atmosphering_speed  \
# 0  Corellia Mining Corporation          150000  36.8                      30
# 1            Incom Corporation           14500  10.4                    1200
# 2         SoroSuub Corporation           10550   3.4                     250
# 3         Sienar Fleet Systems         unknown    6.4                   1200
# 4            Incom corporation         unknown    4.5                    650
#
#   crew passengers cargo_capacity consumables  vehicle_class
# 0   46         30          50000    2 months        wheeled
# ...

# %%
# Save data into csv file
planets_df.to_csv("../data/planets.csv", index=False)
starships_df.to_csv("../data/starships.csv", index=False)
species_df.to_csv("../data/species.csv", index=False)
vehicles_df.to_csv("../data/vehicles.csv", index=False)
